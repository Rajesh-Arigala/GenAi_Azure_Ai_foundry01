# %% [markdown]
# # Azure AI Foundry Environment Setup
#
# This notebook will guide you through setting up your environment for the Azure AI Foundry.
#
# ## Prerequisites
# - Python 3.8 or later
# - Azure subscription with AI services access
# - Basic Python knowledge

# %%
# Install required packages (if not already installed):
# !pip install azure-identity azure-ai-projects
# Out:
# Collecting azure-identity
#   Obtaining dependency information for azure-identity from https://files.pythonhosted.org/packages/49/9a/417b3a533e01953a7c618884df2cb05a71e7b68bdbce4fbdb62349d2a2e8/azure_identity-1.25.3-py3-none-any.whl.metadata
#   Downloading azure_identity-1.25.3-py3-none-any.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.7/91.7 kB 971.0 kB/s eta 0:00:00 0:00:01
# Collecting azure-ai-projects
#   Obtaining dependency information for azure-ai-projects from https://files.pythonhosted.org/packages/8d/f7/290ca39501c06c6e23b46ba9f7f3dfb05ecc928cde105fed85d6845060dd/azure_ai_projects-2.0.1-py3-none-any.whl.metadata
#   Downloading azure_ai_projects-2.0.1-py3-none-any.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 4.0 MB/s eta 0:00:00
# Collecting azure-core>=1.31.0 (from azure-identity)
#   Obtaining dependency information for azure-core>=1.31.0 from https://files.pythonhosted.org/packages/7e/d6/8ebcd05b01a580f086ac9a97fb9fac65c09a4b012161cc97c21a336e880b/azure_core-1.39.0-py3-none-any.whl.metadata
#   Downloading azure_core-1.39.0-py3-none-any.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 kB 3.6 MB/s eta 0:00:00
# Collecting cryptography>=2.5 (from azure-identity)
#   Obtaining dependency information for cryptography>=2.5 from https://files.pythonhosted.org/packages/ec/4d/8e7d7245c79c617d08724e2efa397737715ca0ec830ecb3c91e547302555/cryptography-46.0.6-cp311-abi3-manylinux_2_34_x86_64.whl.metadata
#   Downloading cryptography-46.0.6-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Collecting msal>=1.35.1 (from azure-identity)
#   Obtaining dependency information for msal>=1.35.1 from https://files.pythonhosted.org/packages/96/86/16815fddf056ca998853c6dc525397edf0b43559bb4073a80d2bc7fe8009/msal-1.35.1-py3-none-any.whl.metadata
#   Downloading msal-1.35.1-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity)
#   Obtaining dependency information for msal-extensions>=1.2.0 from https://files.pythonhosted.org/packages/5e/75/bd9b7bb966668920f06b200e84454c8f3566b102183bc55c5473d96cb2b9/msal_extensions-1.3.1-py3-none-any.whl.metadata
#   Downloading msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting typing-extensions>=4.0.0 (from azure-identity)
#   Obtaining dependency information for typing-extensions>=4.0.0 from https://files.pythonhosted.org/packages/18/67/36e9267722cc04a6b9f15c7f3441c2363321a3ea07da7ae0c0707beb2a9c/typing_extensions-4.15.0-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting isodate>=0.6.1 (from azure-ai-projects)
#   Obtaining dependency information for isodate>=0.6.1 from https://files.pythonhosted.org/packages/15/aa/0aca39a37d3c7eb941ba736ede56d689e7be91cab5d9ca846bde3999eba6/isodate-0.7.2-py3-none-any.whl.metadata
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting openai>=2.8.0 (from azure-ai-projects)
#   Obtaining dependency information for openai>=2.8.0 from https://files.pythonhosted.org/packages/2a/9e/5bfa2270f902d5b92ab7d41ce0475b8630572e71e349b2a4996d14bdda93/openai-2.30.0-py3-none-any.whl.metadata
#   Downloading openai-2.30.0-py3-none-any.whl.metadata (29 kB)
# Collecting azure-storage-blob>=12.15.0 (from azure-ai-projects)
#   Obtaining dependency information for azure-storage-blob>=12.15.0 from https://files.pythonhosted.org/packages/d8/3a/6ef2047a072e54e1142718d433d50e9514c999a58f51abfff7902f3a72f8/azure_storage_blob-12.28.0-py3-none-any.whl.metadata
#   Downloading azure_storage_blob-12.28.0-py3-none-any.whl.metadata (26 kB)
# Collecting requests>=2.21.0 (from azure-core>=1.31.0->azure-identity)
#   Obtaining dependency information for requests>=2.21.0 from https://files.pythonhosted.org/packages/d7/8e/7540e8a2036f79a125c1d2ebadf69ed7901608859186c856fa0388ef4197/requests-2.33.1-py3-none-any.whl.metadata
#   Downloading requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting cffi>=2.0.0 (from cryptography>=2.5->azure-identity)
#   Obtaining dependency information for cffi>=2.0.0 from https://files.pythonhosted.org/packages/78/2d/7fa73dfa841b5ac06c7b8855cfc18622132e365f5b81d02230333ff26e9e/cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata
#   Downloading cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.6 kB)
# Collecting PyJWT[crypto]<3,>=1.0.0 (from msal>=1.35.1->azure-identity)
#   Obtaining dependency information for PyJWT[crypto]<3,>=1.0.0 from https://files.pythonhosted.org/packages/e5/7a/8dd906bd22e79e47397a61742927f6747fe93242ef86645ee9092e610244/pyjwt-2.12.1-py3-none-any.whl.metadata
#   Downloading pyjwt-2.12.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting anyio<5,>=3.5.0 (from openai>=2.8.0->azure-ai-projects)
#   Obtaining dependency information for anyio<5,>=3.5.0 from https://files.pythonhosted.org/packages/da/42/e921fccf5015463e32a3cf6ee7f980a6ed0f395ceeaa45060b61d86486c2/anyio-4.13.0-py3-none-any.whl.metadata
#   Downloading anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting distro<2,>=1.7.0 (from openai>=2.8.0->azure-ai-projects)
#   Obtaining dependency information for distro<2,>=1.7.0 from https://files.pythonhosted.org/packages/12/b3/231ffd4ab1fc9d679809f356cebee130ac7daa00d6d6f3206dd4fd137e9e/distro-1.9.0-py3-none-any.whl.metadata
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai>=2.8.0->azure-ai-projects)
#   Obtaining dependency information for httpx<1,>=0.23.0 from https://files.pythonhosted.org/packages/2a/39/e50c7c3a983047577ee07d2a9e53faf5a69493943ec3f6a384bdc792deb2/httpx-0.28.1-py3-none-any.whl.metadata
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.10.0 (from openai>=2.8.0->azure-ai-projects)
#   Obtaining dependency information for jiter<1,>=0.10.0 from https://files.pythonhosted.org/packages/f8/4c/09b93e30e984a187bc8aaa3510e1ec8dcbdcd71ca05d2f56aac0492453aa/jiter-0.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading jiter-0.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting pydantic<3,>=1.9.0 (from openai>=2.8.0->azure-ai-projects)
#   Obtaining dependency information for pydantic<3,>=1.9.0 from https://files.pythonhosted.org/packages/5a/87/b70ad306ebb6f9b585f114d0ac2137d792b48be34d732d60e597c2f8465a/pydantic-2.12.5-py3-none-any.whl.metadata
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 5.7 MB/s eta 0:00:00
# Collecting sniffio (from openai>=2.8.0->azure-ai-projects)
#   Obtaining dependency information for sniffio from https://files.pythonhosted.org/packages/e9/44/75a9c9421471a6c4805dbf2356f7c181a29c1879239abab1ea2cc8f38b40/sniffio-1.3.1-py3-none-any.whl.metadata
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai>=2.8.0->azure-ai-projects)
#   Obtaining dependency information for tqdm>4 from https://files.pythonhosted.org/packages/16/e1/3079a9ff9b8e11b846c6ac5c8b5bfb7ff225eee721825310c91b3b50304f/tqdm-4.67.3-py3-none-any.whl.metadata
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 4.8 MB/s eta 0:00:00
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->openai>=2.8.0->azure-ai-projects)
#   Obtaining dependency information for idna>=2.8 from https://files.pythonhosted.org/packages/0e/61/66938bbb5fc52dbdf84594873d5b51fb1f7c7794e9c0f5bd885f30bc507b/idna-3.11-py3-none-any.whl.metadata
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=2.5->azure-identity)
#   Obtaining dependency information for pycparser from https://files.pythonhosted.org/packages/0c/c3/44f3fbbfa403ea2a7c779186dc20772604442dde72947e7d01069cbe98e3/pycparser-3.0-py3-none-any.whl.metadata
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting certifi (from httpx<1,>=0.23.0->openai>=2.8.0->azure-ai-projects)
#   Obtaining dependency information for certifi from https://files.pythonhosted.org/packages/9a/3c/c17fb3ca2d9c3acff52e30b309f538586f9f5b9c9cf454f3845fc9af4881/certifi-2026.2.25-py3-none-any.whl.metadata
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>=2.8.0->azure-ai-projects)
#   Obtaining dependency information for httpcore==1.* from https://files.pythonhosted.org/packages/7e/f5/f66802a942d491edb555dd61e3a9961140fd64c90bce1eafd741609d334d/httpcore-1.0.9-py3-none-any.whl.metadata
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openai>=2.8.0->azure-ai-projects)
#   Obtaining dependency information for h11>=0.16 from https://files.pythonhosted.org/packages/04/4b/29cac41a4d98d144bf5f6d33995617b185d14b22401f75ca86f384e87ff1/h11-0.16.0-py3-none-any.whl.metadata
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai>=2.8.0->azure-ai-projects)
#   Obtaining dependency information for annotated-types>=0.6.0 from https://files.pythonhosted.org/packages/78/b6/6307fbef88d9b5ee7421e68d78a9f162e0da4900bc5f5793f6d3d0e34fb8/annotated_types-0.7.0-py3-none-any.whl.metadata
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=1.9.0->openai>=2.8.0->azure-ai-projects)
#   Obtaining dependency information for pydantic-core==2.41.5 from https://files.pythonhosted.org/packages/0d/76/941cc9f73529988688a665a5c0ecff1112b3d95ab48f81db5f7606f522d3/pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->openai>=2.8.0->azure-ai-projects)
#   Obtaining dependency information for typing-inspection>=0.4.2 from https://files.pythonhosted.org/packages/dc/9b/47798a6c91d8bdb567fe2698fe81e0c6b7cb7ef4d13da4114b41d239f65d/typing_inspection-0.4.2-py3-none-any.whl.metadata
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.21.0->azure-core>=1.31.0->azure-identity)
#   Obtaining dependency information for charset_normalizer<4,>=2 from https://files.pythonhosted.org/packages/4b/f8/d0118a2f5f23b02cd166fa385c60f9b0d4f9194f574e2b31cef350ad7223/charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Downloading charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 763.8 kB/s eta 0:00:00a 0:00:01
# Collecting urllib3<3,>=1.26 (from requests>=2.21.0->azure-core>=1.31.0->azure-identity)
#   Obtaining dependency information for urllib3<3,>=1.26 from https://files.pythonhosted.org/packages/39/08/aaaad47bc4e9dc8c725e68f9d04865dbcb2052843ff09c97b08904852d84/urllib3-2.6.3-py3-none-any.whl.metadata
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Downloading azure_identity-1.25.3-py3-none-any.whl (192 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.1/192.1 kB 3.3 MB/s eta 0:00:00a 0:00:01
# Downloading azure_ai_projects-2.0.1-py3-none-any.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.6/236.6 kB 7.3 MB/s eta 0:00:00
# Downloading azure_core-1.39.0-py3-none-any.whl (218 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.3/218.3 kB 11.0 MB/s eta 0:00:00
# Downloading azure_storage_blob-12.28.0-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.5/431.5 kB 6.7 MB/s eta 0:00:00:00:01
# Downloading cryptography-46.0.6-cp311-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 15.2 MB/s eta 0:00:0000:0100:01
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading msal-1.35.1-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.9/119.9 kB 19.6 MB/s eta 0:00:00
# Downloading msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Downloading openai-2.30.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.3 MB/s eta 0:00:00:00:01
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 8.4 MB/s eta 0:00:00
# Downloading anyio-4.13.0-py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.4/114.4 kB 16.2 MB/s eta 0:00:00
# Downloading cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (219 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.6/219.6 kB 28.6 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 13.3 MB/s eta 0:00:00
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 14.2 MB/s eta 0:00:00
# Downloading jiter-0.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (360 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.7/360.7 kB 30.4 MB/s eta 0:00:00
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.6/463.6 kB 34.6 MB/s eta 0:00:00
# Downloading pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 38.2 MB/s eta 0:00:00:00:01
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 5.1 MB/s eta 0:00:00
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 13.8 MB/s eta 0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.7/153.7 kB 19.7 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 kB 26.7 MB/s eta 0:00:00
# Downloading idna-3.11-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 9.8 MB/s eta 0:00:00
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 21.7 MB/s eta 0:00:00
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 8.2 MB/s eta 0:00:00
# Downloading pyjwt-2.12.1-py3-none-any.whl (29 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: urllib3, typing-extensions, tqdm, sniffio, PyJWT, pycparser, jiter, isodate, idna, h11, distro, charset_normalizer, certifi, annotated-types, typing-inspection, requests, pydantic-core, httpcore, cffi, anyio, pydantic, httpx, cryptography, azure-core, openai, azure-storage-blob, msal, msal-extensions, azure-identity, azure-ai-projects
# Successfully installed PyJWT-2.12.1 annotated-types-0.7.0 anyio-4.13.0 azure-ai-projects-2.0.1 azure-core-1.39.0 azure-identity-1.25.3 azure-storage-blob-12.28.0 certifi-2026.2.25 cffi-2.0.0 charset_normalizer-3.4.7 cryptography-46.0.6 distro-1.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 isodate-0.7.2 jiter-0.13.0 msal-1.35.1 msal-extensions-1.3.1 openai-2.30.0 pycparser-3.0 pydantic-2.12.5 pydantic-core-2.41.5 requests-2.33.1 sniffio-1.3.1 tqdm-4.67.3 typing-extensions-4.15.0 typing-inspection-0.4.2 urllib3-2.6.3
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Azure Authentication Setup
# First, we'll verify our Azure credentials and setup.

# %%
from azure.identity import DefaultAzureCredential

# Initialize Azure credentials
try:
    credential = DefaultAzureCredential()
    print("✓ Successfully initialized DefaultAzureCredential")
except Exception as e:
    print(f"× Error initializing credentials: {str(e)}")
# Out:
# ✓ Successfully initialized DefaultAzureCredential

# %% [markdown]
# ## Initialize AI Project Client
#
# > **Note:** Before proceeding, ensure you:
# > 1. Create `cred.json` file
# > 2. Update the project connection string in your `cred.json` file
# > 3. Have a Hub and Project already provisioned in Azure AI Foundry

# %% [markdown]
# ## Understanding AIProjectClient
#
# The AIProjectClient is a key component for interacting with Azure AI services that:
#
# - **Manages Connections**: Lists and accesses Azure AI resources like OpenAI models
# - **Handles Authentication**: Securely connects using Azure credentials
# - **Enables Model Access**: Provides interfaces to use AI models and deployments
# - **Manages Project Settings**: Controls configurations for your Azure AI project
#
# The client requires:
# - A project connection string (from Azure AI project settings)
# - Valid Azure credentials
#
# You can find your project connection string in Azure AI Studio under Project Settings:

# %%
import os
import json


def find_file(filename, search_path):
    for root, dirs, files in os.walk(search_path):
        if filename in files:
            return os.path.join(root, filename)
    return None

# Search in the parent directory and its subdirectories
parent_dir = os.path.dirname(os.getcwd())  # Get parent directory
file_path = find_file('cred.json', parent_dir)

print(f"Found cred.json at: {file_path}")

try:
    with open(file_path, 'r') as f:
        loaded_config = json.load(f)
    
    # Print the values to verify
    print("PROJECT_ENDPOINT:", loaded_config['PROJECT_ENDPOINT'])
    
except FileNotFoundError:
    print(f"Could not find file at: {file_path}")
except json.JSONDecodeError:
    print(f"File exists but contains invalid JSON")
# Out:
# Found cred.json at: /workspaces/Azure-ai-foundry01/cred.json
# PROJECT_ENDPOINT: https://sarath-6690-resource.services.ai.azure.com/api/projects/sarath-6690

# %%
import os
from azure.ai.projects import AIProjectClient
from azure.identity import DefaultAzureCredential

project_client = AIProjectClient(
    credential=DefaultAzureCredential(),
    endpoint=loaded_config["PROJECT_ENDPOINT"],
)

# %% [markdown]
# ## Deployments operations

# %%
print("List all deployments:")
for deployment in project_client.deployments.list():
    print(deployment)
# Out:
# List all deployments:

# %% [markdown]
# ## Connections operations

# %%
print("List all connections:")
for connection in project_client.connections.list():
    print(connection)
# Out:
# List all connections:
